# %%
from transformers import AutoProcessor, SiglipImageProcessor

tokenizer = AutoProcessor.from_pretrained("/mnt/33t/cy/mllm_models/Qwen/Qwen3-0.6B")

tok = tokenizer('今天一直在下雨', return='pt')
# Out:
#   Cell In[7], line 5
#     tok = tokenizer('今天一直在下雨', return='pt')
#                                ^
# SyntaxError: invalid syntax

# %%
tok['input_ids'][0]
# Out:
# 100644
